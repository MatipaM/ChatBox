# %% [markdown]
# # API

# %%
# API
import base64
import http.client
import json
import urllib.parse
import ssl

def query_ai(query):
    encoded_query = urllib.parse.quote(query)
    path = f"/api?query={encoded_query}"

    conn = http.client.HTTPSConnection(base64.b64decode("YWkxLnJlZHNoaWZ0ZWQuY28udWs=".encode('utf-8')).decode('utf-8'), context=ssl._create_unverified_context())
    # conn = http.client.HTTPSConnection(base64.b64decode("YWkxLnJlZHNoaWZ0ZWQuY28udWs=".encode('utf-8')).decode('utf-8'))

    try:
        conn.request("GET", path)
        response = conn.getresponse()

        if response.status == 200:
            data = response.read().decode()
            return json.loads(data)
        else:
            print(f"Request failed with status code: {response.status}")
    finally:
        conn.close()

        
query_ai("Give me suggestions of questions to ask")
# Out:
# {'context': [32010,
#   13,
#   29954,
#   573,
#   592,
#   10529,
#   310,
#   5155,
#   304,
#   2244,
#   32007,
#   13,
#   32001,
#   13,
#   29896,
#   29889,
#   1724,
#   526,
#   596,
#   20017,
#   322,
#   298,
#   20838,
#   583,
#   29892,
#   322,
#   2020,
#   437,
#   366,
#   13389,
#   963,
#   29973,
#   13,
#   29906,
#   29889,
#   1815,
#   366,
#   6232,
#   385,
#   7271,
#   393,
#   750,
#   263,
#   7282,
#   10879,
#   373,
#   596,
#   2834,
#   470,
#   18520,
#   29973,
#   13,
#   29941,
#   29889,
#   1128,
#   723,
#   366,
#   8453,
#   596,
#   26001,
#   3114,
#   29892,
#   565,
#   22903,
#   29973,
#   13,
#   29946,
#   29889,
#   512,
#   825,
#   5837,
#   505,
#   18066,
#   267,
#   528,
#   10501,
#   1058,
#   366,
#   526,
#   9826,
#   29973,
#   13,
#   29945,
#   29889,
#   1724,
#   25078,
#   437,
#   366,
#   4459,
#   526,
#   1556,
#   21114,
#   297,
#   278,
#   1857,
#   4982,
#   9999,
#   29892,
#   322,
#   2020,
#   29973,
#   13,
#   29953,
#   29889,
#   1815,
#   366,
#   2649,
#   592,
#   1048,
#   263,
#   2060,
#   393,
#   366,
#   10734,
#   27849,
#   1985,
#   373,
#   322,
#   2020,
#   372,
#   471,
#   6095,
#   5589,
#   292,
#   363,
#   366,
#   29973,
#   13,
#   29955,
#   29889,
#   1128,
#   437,
#   366,
#   7952,
#   4784,
#   411,
#   13661,
#   534,
#   1975,
#   470,
#   3133,
#   5794,
#   11157,
#   596,
#   10257,
#   7134,
#   29973,
#   13,
#   29947,
#   29889,
#   1724,
#   4021,
#   1907,
#   437,
#   366,
#   1106,
#   363,
#   297,
#   7037,
#   23056,
#   21628,
#   470,
#   3815,
#   5144,
#   746,
#   22960,
#   263,
#   716,
#   664,
#   5177,
#   29973,
#   13,
#   29929,
#   29889,
#   1815,
#   366,
#   8453,
#   385,
#   24233,
#   1230,
#   1650,
#   304,
#   263,
#   1108,
#   393,
#   18014,
#   366,
#   470,
#   28585,
#   907,
#   28157,
#   2629,
#   596,
#   1746,
#   29973,
#   13,
#   29896,
#   29900,
#   29889,
#   1128,
#   437,
#   366,
#   17346,
#   664,
#   322,
#   7333,
#   2834,
#   29892,
#   322,
#   825,
#   16650,
#   583,
#   505,
#   9213,
#   366,
#   7344,
#   445,
#   26440,
#   29973,
#   13,
#   29896,
#   29896,
#   29889,
#   1724,
#   17385,
#   1078,
#   366,
#   297,
#   596,
#   6413,
#   29892,
#   322,
#   920,
#   437,
#   366,
#   731,
#   14433,
#   363,
#   7535,
#   6351,
#   635,
#   29973,
#   13,
#   29896,
#   29906,
#   29889,
#   6527,
#   366,
#   6232,
#   263,
#   931,
#   746,
#   366,
#   750,
#   304,
#   7744,
#   9098,
#   304,
#   1735,
#   2629,
#   278,
#   664,
#   6689,
#   470,
#   13661,
#   29973,
#   1128,
#   1258,
#   366,
#   4386,
#   372,
#   29973,
#   13,
#   29896,
#   29941,
#   29889,
#   512,
#   825,
#   5837,
#   505,
#   366,
#   26869,
#   304,
#   596,
#   7881,
#   29892,
#   2845,
#   1549,
#   27886,
#   261,
#   664,
#   470,
#   916,
#   7190,
#   310,
#   3033,
#   5049,
#   29973,
#   13,
#   29896,
#   29946,
#   29889,
#   1724,
#   437,
#   366,
#   2050,
#   408,
#   18853,
#   4021,
#   1907,
#   363,
#   11828,
#   3815,
#   1287,
#   29892,
#   322,
#   920,
#   437,
#   366,
#   9926,
#   261,
#   263,
#   11465,
#   1230,
#   5177,
#   29973,
#   13,
#   29896,
#   29945,
#   29889,
#   1815,
#   366,
#   3867,
#   385,
#   1342,
#   310,
#   746,
#   366,
#   750,
#   304,
#   22222,
#   28410,
#   297,
#   278,
#   3700,
#   310,
#   12959,
#   472,
#   664,
#   29973,
#   13,
#   13,
#   1349,
#   968,
#   5155,
#   4612,
#   5164,
#   21420,
#   3704,
#   7333,
#   20017,
#   29892,
#   10257,
#   27482,
#   29892,
#   25078,
#   29892,
#   7744,
#   3097,
#   29892,
#   26001,
#   29892,
#   907,
#   28157,
#   29892,
#   7881,
#   3033,
#   5049,
#   29892,
#   3815,
#   1287,
#   29892,
#   322,
#   11314,
#   1199,
#   785,
#   13138,
#   263,
#   15171,
#   6270,
#   8004,
#   310,
#   4856,
#   29915,
#   29879,
#   3239,
#   322,
#   1819,
#   29889,
#   32007,
#   13],
#  'created_at': '2024-07-21T17:24:22.197699581Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 386,
#  'eval_duration': 4838990000,
#  'load_duration': 1474141978,
#  'model': 'phi3:latest',
#  'prompt_eval_count': 15,
#  'prompt_eval_duration': 55112000,
#  'response': "1. What are your interests and hobbies, and why do you enjoy them?\n2. Can you share an experience that had a significant impact on your life or perspective?\n3. How would you describe your leadership style, if applicable?\n4. In what ways have challenges shaped who you are today?\n5. What skills do you feel are most valuable in the current job market, and why?\n6. Can you tell me about a project that you particularly enjoyed working on and why it was fulfilling for you?\n7. How do you stay updated with industry trends or continuously improve your professional knowledge?\n8. What qualities do you look for in potential colleagues or team members when joining a new work environment?\n9. Can you describe an innovative solution to a problem that surprised you or demonstrated creativity within your field?\n10. How do you balance work and personal life, and what strategies have helped you maintain this equilibrium?\n11. What motivates you in your career, and how do you set goals for yourself professionally?\n12. Could you share a time when you had to adapt quickly to change within the workplace or industry? How did you handle it?\n13. In what ways have you contributed to your community, either through volunteer work or other forms of engagement?\n14. What do you consider as essential qualities for effective teamwork, and how do you foster a collaborative environment?\n15. Can you provide an example of when you had to demonstrate integrity in the face of pressure at work?\n\nThese questions cover various aspects including personal interests, professional experiences, skills, adaptability, leadership, creativity, community engagement, teamwork, and ethics – providing a comprehensive understanding of someone's background and values.",
#  'total_duration': 6370207828}
